# %%
import EasyPySpin
import cv2
from matplotlib import pyplot as plt
# Create a capture object
capture = EasyPySpin.VideoCapture(3)

# Change channel type
# capture.set(cv2.MAT_TYPE_MASK, 'CV_32F')

# Resize the frame to a 256x256 image
capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 256)
capture.set(cv2.CAP_PROP_FRAME_WIDTH, 256)

# Start the capture loop
# Loop through the frames
# while True:
    
    # Get the next frame
ret, frame = capture.read()
# frame2 = frame[:,::-1]

# Convert color to greyscale
# frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
plt.imshow(frame)
    
    
    
    # Do something with the frame (e.g. display, save to file, etc.)
    # ...
    
# Stop the capture loop
capture.release()
# Out:
# c:\Users\User\.conda\envs\wormspy\lib\site-packages\EasyPySpin\videocapture.py:278: EasyPySpinWarning: 'Height' is not writable
#   return self.set_pyspin_value("Height", value)
# c:\Users\User\.conda\envs\wormspy\lib\site-packages\EasyPySpin\videocapture.py:274: EasyPySpinWarning: 'Width' is not writable
#   return self.set_pyspin_value("Width", value)
